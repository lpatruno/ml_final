# %% [markdown]
# The goal of this worksheet is to tune hyperparamaters for an L2 regularized Logistic Regression model and an SVM model. This includes a grid search over hyperparams as well as a feature selection process. The Logistic Regression and Linear SVM models used will be from the scikit-learn package.
# <br><br>The feature selection routine will validate models by training a model on a training set and validating the model on a test set. After finding the optimal number of parameters for a model, we will perform a cross validation of the model across the entire data set.
# <br><br>Hence the procedure is as follows:
#    * Read in the data, split the data into a training and testing set (.75 to .25 sizes)
#    * Pick out a grid of hyperparameter values for the L2 regularized Logistic Regression model
#    and the Linear Support Vector Machine. If time allows, we can use nonlinear kernels for
#    the SVM.
#    * Feed the classifier and the training data into the feature_selection routine. The routine
#    is to return the features that produced the lowest training error for the model. Training
#    error is used here to reduce the bias of training the model (See ITSL)
#    * After the feature selection routine is carried out, validate each model using a cross
#    validation approach. This means getting a cross validation score for each model over the
#    same grid search space.

# %%
import copy
import itertools
from time import time

import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression

from get_data import data
from featureselection import FeatureSelection

# %%
df = data()

# %% [markdown]
# ## 11/29/2015

# %%
grid_search = []

for c in np.linspace(.1, 5.0, 50):
    for max_iter in [10, 50, 100]:
        print '\n\nL2 with c={} and max_iter={}\n'.format(c, max_iter)
        classifier = LogisticRegression(C=c, max_iter=max_iter)
        feature_selection = FeatureSelection(classifier, df)
        features, error = feature_selection.feature_reduce()
        grid_search.append({'classifier: ': 'Logistic L2', 'C':c, 'max_iter':max_iter, 'features':features, 'error':error})
        print grid_search
# Out:
# L2 with c=0.1 and max_iter=10
#
# Calculating best 13 features
# Training error: 0.206552006552
# Calculating best 12 features
# Training error: 0.206552006552
# Calculating best 11 features
# Training error: 0.206552006552
# Calculating best 10 features
# Training error: 0.206552006552
# Calculating best 9 features
# Training error: 0.206552006552
# Calculating best 8 features
# Training error: 0.206552006552
# Calculating best 7 features
# Training error: 0.206552006552
# Calculating best 6 features
# Training error: 0.206552006552
# Calculating best 5 features
# Training error: 0.206552006552
# Calculating best 4 features
# Training error: 0.206552006552
# Calculating best 3 features
# Training error: 0.206592956593
# Calculating best 2 features
# Training error: 0.209131859132
# Calculating best 1 features
# Training error: 0.222809172809
# Total time taken: 17.3646306992
#
# Best n: 13
# Calculating best 13 features
# Total time taken: 21.0951547623
# Lowest Test error: 0.200589608156
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}]
#
#
# L2 with c=0.1 and max_iter=50
#
# Calculating best 13 features
# Training error: 0.150245700246
# Calculating best 12 features
# Training error: 0.149262899263
# Calculating best 11 features
# Training error: 0.148976248976
# Calculating best 10 features
# Training error: 0.149836199836
# Calculating best 9 features
# Training error: 0.149877149877
# Calculating best 8 features
# Training error: 0.150491400491
# Calculating best 7 features
# Training error: 0.151023751024
# Calculating best 6 features
# Training error: 0.151678951679
# Calculating best 5 features
# Training error: 0.153972153972
# Calculating best 4 features
# Training error: 0.156838656839
# Calculating best 3 features
# Training error: 0.1638001638
# Calculating best 2 features
# Training error: 0.180671580672
# Calculating best 1 features
# Training error: 0.222031122031
# Total time taken: 42.6817874908
#
# Best n: 11
# Calculating best 11 features
# Total time taken: 169.155915976
# Lowest Test error: 0.144208328215
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14420832821520702}]
#
#
# L2 with c=0.1 and max_iter=100
#
# Calculating best 13 features
# Training error: 0.148443898444
# Calculating best 12 features
# Training error: 0.147256347256
# Calculating best 11 features
# Training error: 0.147338247338
# Calculating best 10 features
# Training error: 0.148443898444
# Calculating best 9 features
# Training error: 0.148484848485
# Calculating best 8 features
# Training error: 0.149508599509
# Calculating best 7 features
# Training error: 0.149344799345
# Calculating best 6 features
# Training error: 0.151187551188
# Calculating best 5 features
# Training error: 0.152252252252
# Calculating best 4 features
# Training error: 0.157289107289
# Calculating best 3 features
# Training error: 0.162776412776
# Calculating best 2 features
# Training error: 0.17972972973
# Calculating best 1 features
# Training error: 0.220024570025
# Total time taken: 42.6836733818
#
# Best n: 12
# Calculating best 12 features
# Total time taken: 74.2903523445
# Lowest Test error: 0.14924456455
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14420832821520702}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14924456454980961}]
#
#
# L2 with c=0.2 and max_iter=10
#
# Calculating best 13 features
# Training error: 0.205773955774
# Calculating best 12 features
# Training error: 0.205773955774
# Calculating best 11 features
# Training error: 0.205773955774
# Calculating best 10 features
# Training error: 0.205773955774
# Calculating best 9 features
# Training error: 0.205773955774
# Calculating best 8 features
# Training error: 0.205773955774
# Calculating best 7 features
# Training error: 0.205773955774
# Calculating best 6 features
# Training error: 0.205773955774
# Calculating best 5 features
# Training error: 0.205773955774
# Calculating best 4 features
# Training error: 0.205814905815
# Calculating best 3 features
# Training error: 0.205896805897
# Calculating best 2 features
# Training error: 0.208476658477
# Calculating best 1 features
# Training error: 0.222153972154
# Total time taken: 16.5351581573
#
# Best n: 13
# Calculating best 13 features
# Total time taken: 19.9347894192
# Lowest Test error: 0.199975432993
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14420832821520702}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14924456454980961}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19997543299348974}]
#
#
# L2 with c=0.2 and max_iter=50
#
# Calculating best 13 features
# Training error: 0.147665847666
# Calculating best 12 features
# Training error: 0.146805896806
# Calculating best 11 features
# Training error: 0.145945945946
# Calculating best 10 features
# Training error: 0.146232596233
# Calculating best 9 features
# Training error: 0.14656019656
# Calculating best 8 features
# Training error: 0.14696969697
# Calculating best 7 features
# Training error: 0.147911547912
# Calculating best 6 features
# Training error: 0.148730548731
# Calculating best 5 features
# Training error: 0.151105651106
# Calculating best 4 features
# Training error: 0.154504504505
# Calculating best 3 features
# Training error: 0.161916461916
# Calculating best 2 features
# Training error: 0.178542178542
# Calculating best 1 features
# Training error: 0.218837018837
# Total time taken: 44.7452459335
#
# Best n: 11
# Calculating best 11 features
# Total time taken: 169.945285559
# Lowest Test error: 0.15071858494
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14420832821520702}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14924456454980961}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19997543299348974}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.150718584940425}]
#
#
# L2 with c=0.2 and max_iter=100
#
# Calculating best 13 features
# Training error: 0.148853398853
# Calculating best 12 features
# Training error: 0.14954954955
# Calculating best 11 features
# Training error: 0.149262899263
# Calculating best 10 features
# Training error: 0.149672399672
# Calculating best 9 features
# Training error: 0.150245700246
# Calculating best 8 features
# Training error: 0.150614250614
# Calculating best 7 features
# Training error: 0.151269451269
# Calculating best 6 features
# Training error: 0.152416052416
# Calculating best 5 features
# Training error: 0.153726453726
# Calculating best 4 features
# Training error: 0.157493857494
# Calculating best 3 features
# Training error: 0.162817362817
# Calculating best 2 features
# Training error: 0.179647829648
# Calculating best 1 features
# Training error: 0.220597870598
# Total time taken: 41.5689704418
#
# Best n: 13
# Calculating best 13 features
# Total time taken: 46.7146956921
# Lowest Test error: 0.14445399828
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14420832821520702}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14924456454980961}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19997543299348974}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.150718584940425}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14445399828030958}]
#
#
# L2 with c=0.3 and max_iter=10
#
# Calculating best 13 features
# Training error: 0.20217035217
# Calculating best 12 features
# Training error: 0.202088452088
# Calculating best 11 features
# Training error: 0.202088452088
# Calculating best 10 features
# Training error: 0.202088452088
# Calculating best 9 features
# Training error: 0.202088452088
# Calculating best 8 features
# Training error: 0.202088452088
# Calculating best 7 features
# Training error: 0.202088452088
# Calculating best 6 features
# Training error: 0.202088452088
# Calculating best 5 features
# Training error: 0.202088452088
# Calculating best 4 features
# Training error: 0.202088452088
# Calculating best 3 features
# Training error: 0.202088452088
# Calculating best 2 features
# Training error: 0.204381654382
# Calculating best 1 features
# Training error: 0.219041769042
# Total time taken: 16.4928252697
#
# Best n: 12
# Calculating best 12 features
# Total time taken: 36.0909972191
# Lowest Test error: 0.195430536789
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14420832821520702}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14924456454980961}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19997543299348974}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.150718584940425}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14445399828030958}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19543053678909228}]
#
#
# L2 with c=0.3 and max_iter=50
#
# Calculating best 13 features
# Training error: 0.146519246519
# Calculating best 12 features
# Training error: 0.146887796888
# Calculating best 11 features
# Training error: 0.147010647011
# Calculating best 10 features
# Training error: 0.146887796888
# Calculating best 9 features
# Training error: 0.14656019656
# Calculating best 8 features
# Training error: 0.147133497133
# Calculating best 7 features
# Training error: 0.148607698608
# Calculating best 6 features
# Training error: 0.14914004914
# Calculating best 5 features
# Training error: 0.150532350532
# Calculating best 4 features
# Training error: 0.155569205569
# Calculating best 3 features
# Training error: 0.162162162162
# Calculating best 2 features
# Training error: 0.178583128583
# Calculating best 1 features
# Training error: 0.220311220311
# Total time taken: 44.3681807518
#
# Best n: 13
# Calculating best 13 features
# Total time taken: 50.1839625835
# Lowest Test error: 0.152683945461
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14420832821520702}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14924456454980961}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19997543299348974}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.150718584940425}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14445399828030958}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19543053678909228}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15268394546124553}]
#
#
# L2 with c=0.3 and max_iter=100
#
# Calculating best 13 features
# Training error: 0.147461097461
# Calculating best 12 features
# Training error: 0.147624897625
# Calculating best 11 features
# Training error: 0.146642096642
# Calculating best 10 features
# Training error: 0.147133497133
# Calculating best 9 features
# Training error: 0.148075348075
# Calculating best 8 features
# Training error: 0.148648648649
# Calculating best 7 features
# Training error: 0.149467649468
# Calculating best 6 features
# Training error: 0.151433251433
# Calculating best 5 features
# Training error: 0.152948402948
# Calculating best 4 features
# Training error: 0.157002457002
# Calculating best 3 features
# Training error: 0.161875511876
# Calculating best 2 features
# Training error: 0.179197379197
# Calculating best 1 features
# Training error: 0.219656019656
# Total time taken: 43.312830925
#
# Best n: 11
# Calculating best 11 features
# Total time taken: 172.200682163
# Lowest Test error: 0.150350079843
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14420832821520702}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14924456454980961}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19997543299348974}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.150718584940425}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14445399828030958}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19543053678909228}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15268394546124553}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 100, 'features': ('age', 'workclass', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15035007984277116}]
#
#
# L2 with c=0.4 and max_iter=10
#
# Calculating best 13 features
# Training error: 0.203685503686
# Calculating best 12 features
# Training error: 0.203685503686
# Calculating best 11 features
# Training error: 0.203685503686
# Calculating best 10 features
# Training error: 0.203685503686
# Calculating best 9 features
# Training error: 0.203685503686
# Calculating best 8 features
# Training error: 0.203685503686
# Calculating best 7 features
# Training error: 0.203685503686
# Calculating best 6 features
# Training error: 0.203685503686
# Calculating best 5 features
# Training error: 0.203685503686
# Calculating best 4 features
# Training error: 0.203685503686
# Calculating best 3 features
# Training error: 0.203726453726
# Calculating best 2 features
# Training error: 0.207166257166
# Calculating best 1 features
# Training error: 0.221007371007
# Total time taken: 16.1635448933
#
# Best n: 13
# Calculating best 13 features
# Total time taken: 19.5234484673
# Lowest Test error: 0.205625844491
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14420832821520702}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14924456454980961}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19997543299348974}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.150718584940425}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14445399828030958}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19543053678909228}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15268394546124553}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 100, 'features': ('age', 'workclass', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15035007984277116}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20562584449084875}]
#
#
# L2 with c=0.4 and max_iter=50
#
# Calculating best 13 features
# Training error: 0.150286650287
# Calculating best 12 features
# Training error: 0.150040950041
# Calculating best 11 features
# Training error: 0.149713349713
# Calculating best 10 features
# Training error: 0.150081900082
# Calculating best 9 features
# Training error: 0.150081900082
# Calculating best 8 features
# Training error: 0.150122850123
# Calculating best 7 features
# Training error: 0.151556101556
# Calculating best 6 features
# Training error: 0.152661752662
# Calculating best 5 features
# Training error: 0.153276003276
# Calculating best 4 features
# Training error: 0.157043407043
# Calculating best 3 features
# Training error: 0.163390663391
# Calculating best 2 features
# Training error: 0.180835380835
# Calculating best 1 features
# Training error: 0.220515970516
# Total time taken: 46.5705616474
#
# Best n: 11
# Calculating best 11 features
# Total time taken: 178.367028475
# Lowest Test error: 0.141997297629
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14420832821520702}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14924456454980961}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19997543299348974}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.150718584940425}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14445399828030958}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19543053678909228}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15268394546124553}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 100, 'features': ('age', 'workclass', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15035007984277116}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20562584449084875}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14199729762928393}]
#
#
# L2 with c=0.4 and max_iter=100
#
# Calculating best 13 features
# Training error: 0.147870597871
# Calculating best 12 features
# Training error: 0.147461097461
# Calculating best 11 features
# Training error: 0.147542997543
# Calculating best 10 features
# Training error: 0.146887796888
# Calculating best 9 features
# Training error: 0.147297297297
# Calculating best 8 features
# Training error: 0.148853398853
# Calculating best 7 features
# Training error: 0.14954954955
# Calculating best 6 features
# Training error: 0.150696150696
# Calculating best 5 features
# Training error: 0.15257985258
# Calculating best 4 features
# Training error: 0.155978705979
# Calculating best 3 features
# Training error: 0.161343161343
# Calculating best 2 features
# Training error: 0.17800982801
# Calculating best 1 features
# Training error: 0.219533169533
# Total time taken: 45.4369599819
#
# Best n: 10
# Calculating best 10 features
# Total time taken: 372.274913311
# Lowest Test error: 0.148507554355
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14420832821520702}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14924456454980961}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19997543299348974}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.150718584940425}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14445399828030958}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19543053678909228}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15268394546124553}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 100, 'features': ('age', 'workclass', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15035007984277116}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20562584449084875}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14199729762928393}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 100, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14850755435450191}]
#
#
# L2 with c=0.5 and max_iter=10
#
# Calculating best 13 features
# Training error: 0.201924651925
# Calculating best 12 features
# Training error: 0.201924651925
# Calculating best 11 features
# Training error: 0.201924651925
# Calculating best 10 features
# Training error: 0.201924651925
# Calculating best 9 features
# Training error: 0.201924651925
# Calculating best 8 features
# Training error: 0.201924651925
# Calculating best 7 features
# Training error: 0.201924651925
# Calculating best 6 features
# Training error: 0.201924651925
# Calculating best 5 features
# Training error: 0.201924651925
# Calculating best 4 features
# Training error: 0.202047502048
# Calculating best 3 features
# Training error: 0.202088452088
# Calculating best 2 features
# Training error: 0.2042997543
# Calculating best 1 features
# Training error: 0.217158067158
# Total time taken: 16.2191140652
#
# Best n: 14
# Calculating best 14 features
# Total time taken: 16.4791030884
# Lowest Test error: 0.212627441346
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14420832821520702}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14924456454980961}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19997543299348974}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.150718584940425}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14445399828030958}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19543053678909228}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15268394546124553}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 100, 'features': ('age', 'workclass', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15035007984277116}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20562584449084875}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14199729762928393}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 100, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14850755435450191}, {'classifier: ': 'Logistic L2', 'C': 0.5, 'max_iter': 10, 'features': ('age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.21262744134627198}]
#
#
# L2 with c=0.5 and max_iter=50
#
# Calculating best 13 features
# Training error: 0.149918099918
# Calculating best 12 features
# Training error: 0.149631449631
# Calculating best 11 features
# Training error: 0.148771498771
# Calculating best 10 features
# Training error: 0.149754299754
# Calculating best 9 features
# Training error: 0.149385749386
# Calculating best 8 features
# Training error: 0.150163800164
# Calculating best 7 features
# Training error: 0.150982800983
# Calculating best 6 features
# Training error: 0.152661752662
# Calculating best 5 features
# Training error: 0.155896805897
# Calculating best 4 features
# Training error: 0.160032760033
# Calculating best 3 features
# Training error: 0.164496314496
# Calculating best 2 features
# Training error: 0.1819000819
# Calculating best 1 features
# Training error: 0.223177723178
# Total time taken: 44.4856483936
#
# Best n: 11
# Calculating best 11 features
# Total time taken: 168.875742674
# Lowest Test error: 0.142488637759
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14420832821520702}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14924456454980961}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19997543299348974}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.150718584940425}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14445399828030958}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19543053678909228}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15268394546124553}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 100, 'features': ('age', 'workclass', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15035007984277116}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20562584449084875}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14199729762928393}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 100, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14850755435450191}, {'classifier: ': 'Logistic L2', 'C': 0.5, 'max_iter': 10, 'features': ('age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.21262744134627198}, {'classifier: ': 'Logistic L2', 'C': 0.5, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'hours-per-week', 'native-country'), 'error': 0.14248863775948906}]
#
#
# L2 with c=0.5 and max_iter=100
#
# Calculating best 13 features
# Training error: 0.148648648649
# Calculating best 12 features
# Training error: 0.147911547912
# Calculating best 11 features
# Training error: 0.149262899263
# Calculating best 10 features
# Training error: 0.149017199017
# Calculating best 9 features
# Training error: 0.149099099099
# Calculating best 8 features
# Training error: 0.150532350532
# Calculating best 7 features
# Training error: 0.151842751843
# Calculating best 6 features
# Training error: 0.151883701884
# Calculating best 5 features
# Training error: 0.153235053235
# Calculating best 4 features
# Training error: 0.157903357903
# Calculating best 3 features
# Training error: 0.162285012285
# Calculating best 2 features
# Training error: 0.180917280917
# Calculating best 1 features
# Training error: 0.221785421785
# Total time taken: 42.4380745888
#
# Best n: 12
# Calculating best 12 features
# Total time taken: 73.9025728703
# Lowest Test error: 0.145682348606
# ...
#
#
# L2 with c=2.6 and max_iter=10
#
# Calculating best 13 features
# Training error: 0.204914004914
# Calculating best 12 features
# Training error: 0.204914004914
# Calculating best 11 features
# Training error: 0.204914004914
# Calculating best 10 features
# Training error: 0.204914004914
# Calculating best 9 features
# Training error: 0.204914004914
# Calculating best 8 features
# Training error: 0.204914004914
# Calculating best 7 features
# Training error: 0.204914004914
# Calculating best 6 features
# Training error: 0.204914004914
# Calculating best 5 features
# Training error: 0.20343980344
# Calculating best 4 features
# Training error: 0.203480753481
# Calculating best 3 features
# Training error: 0.203521703522
# Calculating best 2 features
# Training error: 0.206592956593
# Calculating best 1 features
# Training error: 0.220843570844
# Total time taken: 16.7874617577
#
# Best n: 5
# Calculating best 5 features
# Total time taken: 213.50997901
# Lowest Test error: 0.164476108586
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14420832821520702}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14924456454980961}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19997543299348974}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.150718584940425}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14445399828030958}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19543053678909228}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15268394546124553}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 100, 'features': ('age', 'workclass', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15035007984277116}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20562584449084875}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14199729762928393}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 100, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14850755435450191}, {'classifier: ': 'Logistic L2', 'C': 0.5, 'max_iter': 10, 'features': ('age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.21262744134627198}, {'classifier: ': 'Logistic L2', 'C': 0.5, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'hours-per-week', 'native-country'), 'error': 0.14248863775948906}, {'classifier: ' ...
#
#
# L2 with c=2.6 and max_iter=50
#
# Calculating best 13 features
# Training error: 0.147010647011
# Calculating best 12 features
# Training error: 0.146846846847
# Calculating best 11 features
# Training error: 0.146723996724
# Calculating best 10 features
# Training error: 0.147051597052
# Calculating best 9 features
# Training error: 0.147338247338
# Calculating best 8 features
# Training error: 0.147911547912
# Calculating best 7 features
# Training error: 0.148484848485
# Calculating best 6 features
# Training error: 0.149058149058
# Calculating best 5 features
# Training error: 0.15303030303
# Calculating best 4 features
# Training error: 0.156306306306
# Calculating best 3 features
# Training error: 0.162448812449
# Calculating best 2 features
# Training error: 0.179934479934
# Calculating best 1 features
# Training error: 0.220188370188
# Total time taken: 45.4563438892
#
# Best n: 11
# Calculating best 11 features
# Total time taken: 172.044481993
# Lowest Test error: 0.149121729517
# [{'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20058960815624616}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14420832821520702}, {'classifier: ': 'Logistic L2', 'C': 0.10000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14924456454980961}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19997543299348974}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.150718584940425}, {'classifier: ': 'Logistic L2', 'C': 0.20000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14445399828030958}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19543053678909228}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15268394546124553}, {'classifier: ': 'Logistic L2', 'C': 0.30000000000000004, 'max_iter': 100, 'features': ('age', 'workclass', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15035007984277116}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 10, 'features': ('age', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.20562584449084875}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14199729762928393}, {'classifier: ': 'Logistic L2', 'C': 0.40000000000000002, 'max_iter': 100, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14850755435450191}, {'classifier: ': 'Logistic L2', 'C': 0.5, 'max_iter': 10, 'features': ('age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.21262744134627198}, {'classifier: ': 'Logistic L2', 'C': 0.5, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'hours-per-week', 'native-country'), 'error': 0.14248863775948906}, {'classifier: ' ...
#
#
# L2 with c=2.6 and max_iter=100
#
# Calculating best 13 features
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-fd987e362211> in <module>()
#       6         classifier = LogisticRegression(C=c, max_iter=max_iter)
#       7         feature_selection = FeatureSelection(classifier, df)
# ----> 8         features, error = feature_selection.feature_reduce()
#       9         grid_search.append({'classifier: ': 'Logistic L2', 'C':c, 'max_iter':max_iter, 'features':features, 'error':error})
#      10         print grid_search
#
# /Users/luigi/Documents/MS Comp Sci/Semester 3/Machine Learning/final_project/featureselection.py in feature_reduce(self)
#      38         """
#      39         # Get the best number of features
# ---> 40         n = self._get_best_n()
#      41
#      42         # Get all subsets of features of size n
#
# /Users/luigi/Documents/MS Comp Sci/Semester 3/Machine Learning/final_project/featureselection.py in _get_best_n(self)
#      87
#      88             # Get best set of features of size n and lowest error
# ---> 89             best_n_features, best_n_error = self._best_n_features(n_feature_subsets)
#      90             print 'Training error: {}'.format(best_n_error)
#      91             best_n_model.append((best_n_features, best_n_error))
#
# /Users/luigi/Documents/MS Comp Sci/Semester 3/Machine Learning/final_project/featureselection.py in _best_n_features(self, feature_subsets, validation_set)
#     134             classifier = copy.deepcopy(self.classifier)
#     135             t0 = time()
# --> 136             classifier.fit(X_train_sub, y)
#     137
#     138             if validation_set:
#
# /Users/luigi/Documents/DataScience/venv/lib/python2.7/site-packages/sklearn/linear_model/logistic.pyc in fit(self, X, y, sample_weight)
#    1152                 X, y, self.C, self.fit_intercept, self.intercept_scaling,
#    1153                 self.class_weight, self.penalty, self.dual, self.verbose,
# -> 1154                 self.max_iter, self.tol, self.random_state)
#    1155             self.n_iter_ = np.array([n_iter_])
#    1156             return self
#
# /Users/luigi/Documents/DataScience/venv/lib/python2.7/site-packages/sklearn/svm/base.pyc in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon)
#     914         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     915         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
# --> 916         epsilon)
#     917     # Regarding rnd.randint(..) in the above signature:
#     918     # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# KeyboardInterrupt:

# %%
with open('log_reg_l2.txt', 'w') as f:
    for it in grid_search:
        f.write('{}\n'.format(it))

# %% [markdown]
# ## 11/30/2015

# %%
grid_search = []

for c in np.linspace(2.6, 5.0, 25):
    for max_iter in [10, 50, 100]:
        print '\n\nL2 with c={} and max_iter={}\n'.format(c, max_iter)
        classifier = LogisticRegression(C=c, max_iter=max_iter)
        feature_selection = FeatureSelection(classifier, df)
        features, error = feature_selection.feature_reduce()
        grid_search.append({'classifier: ': 'Logistic L2', 'C':c, 'max_iter':max_iter, 'features':features, 'error':error})
        print grid_search
# Out:
# L2 with c=2.6 and max_iter=10
#
# Calculating best 13 features
# Training error: 0.200941850942
# Calculating best 12 features
# Training error: 0.198157248157
# Calculating best 11 features
# Training error: 0.166871416871
# Calculating best 10 features
# Training error: 0.165192465192
# Calculating best 9 features
# Training error: 0.16420966421
# Calculating best 8 features
# Training error: 0.164332514333
# Calculating best 7 features
# Training error: 0.164946764947
# Calculating best 6 features
# Training error: 0.166011466011
# Calculating best 5 features
# Training error: 0.166175266175
# Calculating best 4 features
# Training error: 0.168877968878
# Calculating best 3 features
# Training error: 0.170925470925
# Calculating best 2 features
# Training error: 0.177764127764
# Calculating best 1 features
# Training error: 0.21855036855
# Total time taken: 23.5229580402
#
# Best n: 9
# Calculating best 9 features
# Total time taken: 349.465702772
# Lowest Test error: 0.169143839823
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}]
#
#
# L2 with c=2.6 and max_iter=50
#
# Calculating best 13 features
# Training error: 0.148116298116
# Calculating best 12 features
# Training error: 0.146887796888
# Calculating best 11 features
# Training error: 0.147010647011
# Calculating best 10 features
# Training error: 0.147870597871
# Calculating best 9 features
# Training error: 0.14782964783
# Calculating best 8 features
# Training error: 0.147542997543
# Calculating best 7 features
# Training error: 0.148648648649
# Calculating best 6 features
# Training error: 0.149836199836
# Calculating best 5 features
# Training error: 0.151556101556
# Calculating best 4 features
# Training error: 0.157166257166
# Calculating best 3 features
# Training error: 0.161670761671
# Calculating best 2 features
# Training error: 0.179606879607
# Calculating best 1 features
# Training error: 0.218755118755
# Total time taken: 44.408039093
#
# Best n: 12
# Calculating best 12 features
# Total time taken: 77.3635561466
# Lowest Test error: 0.149858739713
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}]
#
#
# L2 with c=2.6 and max_iter=100
#
# Calculating best 13 features
# Training error: 0.146437346437
# Calculating best 12 features
# Training error: 0.14696969697
# Calculating best 11 features
# Training error: 0.147952497952
# Calculating best 10 features
# Training error: 0.146764946765
# Calculating best 9 features
# Training error: 0.147502047502
# Calculating best 8 features
# Training error: 0.148321048321
# Calculating best 7 features
# Training error: 0.148771498771
# Calculating best 6 features
# Training error: 0.149221949222
# Calculating best 5 features
# Training error: 0.152252252252
# Calculating best 4 features
# Training error: 0.155773955774
# Calculating best 3 features
# Training error: 0.162203112203
# Calculating best 2 features
# Training error: 0.178501228501
# Calculating best 1 features
# Training error: 0.218468468468
# Total time taken: 46.0743083954
#
# Best n: 13
# Calculating best 13 features
# Total time taken: 52.4863967896
# Lowest Test error: 0.150104409778
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}]
#
#
# L2 with c=2.7 and max_iter=10
#
# Calculating best 13 features
# Training error: 0.206183456183
# Calculating best 12 features
# Training error: 0.186609336609
# Calculating best 11 features
# Training error: 0.168591318591
# Calculating best 10 features
# Training error: 0.167158067158
# Calculating best 9 features
# Training error: 0.167280917281
# Calculating best 8 features
# Training error: 0.168386568387
# Calculating best 7 features
# Training error: 0.168673218673
# Calculating best 6 features
# Training error: 0.16895986896
# Calculating best 5 features
# Training error: 0.169287469287
# Calculating best 4 features
# Training error: 0.170106470106
# Calculating best 3 features
# Training error: 0.172891072891
# Calculating best 2 features
# Training error: 0.180753480753
# Calculating best 1 features
# Training error: 0.22199017199
# Total time taken: 21.4833738804
#
# Best n: 10
# Calculating best 10 features
# Total time taken: 200.826519728
# Lowest Test error: 0.163493428326
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16349342832575853}]
#
#
# L2 with c=2.7 and max_iter=50
#
# Calculating best 13 features
# Training error: 0.150081900082
# Calculating best 12 features
# Training error: 0.149303849304
# Calculating best 11 features
# Training error: 0.148525798526
# Calculating best 10 features
# Training error: 0.148771498771
# Calculating best 9 features
# Training error: 0.149672399672
# Calculating best 8 features
# Training error: 0.15
# Calculating best 7 features
# Training error: 0.150532350532
# Calculating best 6 features
# Training error: 0.151269451269
# Calculating best 5 features
# Training error: 0.155364455364
# Calculating best 4 features
# Training error: 0.157780507781
# Calculating best 3 features
# Training error: 0.163963963964
# Calculating best 2 features
# Training error: 0.181081081081
# Calculating best 1 features
# Training error: 0.221457821458
# Total time taken: 44.5255446434
#
# Best n: 11
# Calculating best 11 features
# Total time taken: 173.873095036
# Lowest Test error: 0.142242967694
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16349342832575853}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14224296769438649}]
#
#
# L2 with c=2.7 and max_iter=100
#
# Calculating best 13 features
# Training error: 0.148443898444
# Calculating best 12 features
# Training error: 0.147624897625
# Calculating best 11 features
# Training error: 0.147665847666
# Calculating best 10 features
# Training error: 0.147747747748
# Calculating best 9 features
# Training error: 0.147461097461
# Calculating best 8 features
# Training error: 0.14782964783
# Calculating best 7 features
# Training error: 0.149180999181
# Calculating best 6 features
# Training error: 0.149918099918
# Calculating best 5 features
# Training error: 0.152538902539
# Calculating best 4 features
# Training error: 0.157248157248
# Calculating best 3 features
# Training error: 0.163472563473
# Calculating best 2 features
# Training error: 0.179606879607
# Calculating best 1 features
# Training error: 0.21941031941
# Total time taken: 47.0379543304
#
# Best n: 9
# Calculating best 9 features
# Total time taken: 682.624228477
# Lowest Test error: 0.148016214224
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16349342832575853}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14224296769438649}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.14801621422429678}]
#
#
# L2 with c=2.8 and max_iter=10
#
# Calculating best 13 features
# Training error: 0.204709254709
# Calculating best 12 features
# Training error: 0.204627354627
# Calculating best 11 features
# Training error: 0.204627354627
# Calculating best 10 features
# Training error: 0.204627354627
# Calculating best 9 features
# Training error: 0.204627354627
# Calculating best 8 features
# Training error: 0.204627354627
# Calculating best 7 features
# Training error: 0.204627354627
# Calculating best 6 features
# Training error: 0.204627354627
# Calculating best 5 features
# Training error: 0.204627354627
# Calculating best 4 features
# Training error: 0.204627354627
# Calculating best 3 features
# Training error: 0.204627354627
# Calculating best 2 features
# Training error: 0.206183456183
# Calculating best 1 features
# Training error: 0.220434070434
# Total time taken: 17.0115551949
#
# Best n: 12
# Calculating best 12 features
# Total time taken: 37.7254590988
# Lowest Test error: 0.190025795357
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16349342832575853}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14224296769438649}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.14801621422429678}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19002579535683572}]
#
#
# L2 with c=2.8 and max_iter=50
#
# Calculating best 13 features
# Training error: 0.148361998362
# Calculating best 12 features
# Training error: 0.147502047502
# Calculating best 11 features
# Training error: 0.14782964783
# Calculating best 10 features
# Training error: 0.148116298116
# Calculating best 9 features
# Training error: 0.147706797707
# Calculating best 8 features
# Training error: 0.148730548731
# Calculating best 7 features
# Training error: 0.149385749386
# Calculating best 6 features
# Training error: 0.150532350532
# Calculating best 5 features
# Training error: 0.152006552007
# Calculating best 4 features
# Training error: 0.157084357084
# Calculating best 3 features
# Training error: 0.161875511876
# Calculating best 2 features
# Training error: 0.178746928747
# Calculating best 1 features
# Training error: 0.219246519247
# Total time taken: 47.3850393295
#
# Best n: 12
# Calculating best 12 features
# Total time taken: 82.8161692619
# Lowest Test error: 0.148998894485
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16349342832575853}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14224296769438649}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.14801621422429678}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19002579535683572}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14899889448470705}]
#
#
# L2 with c=2.8 and max_iter=100
#
# Calculating best 13 features
# Training error: 0.150081900082
# Calculating best 12 features
# Training error: 0.148566748567
# Calculating best 11 features
# Training error: 0.149385749386
# Calculating best 10 features
# Training error: 0.148771498771
# Calculating best 9 features
# Training error: 0.149672399672
# Calculating best 8 features
# Training error: 0.150040950041
# Calculating best 7 features
# Training error: 0.151064701065
# Calculating best 6 features
# Training error: 0.15217035217
# Calculating best 5 features
# Training error: 0.155528255528
# Calculating best 4 features
# Training error: 0.156347256347
# Calculating best 3 features
# Training error: 0.164291564292
# Calculating best 2 features
# Training error: 0.181367731368
# Calculating best 1 features
# Training error: 0.22113022113
# Total time taken: 47.4704728127
#
# Best n: 12
# Calculating best 12 features
# Total time taken: 81.4107527733
# Lowest Test error: 0.142857142857
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16349342832575853}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14224296769438649}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.14801621422429678}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19002579535683572}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14899889448470705}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.1428571428571429}]
#
#
# L2 with c=2.9 and max_iter=10
#
# Calculating best 13 features
# Training error: 0.204340704341
# Calculating best 12 features
# Training error: 0.204258804259
# Calculating best 11 features
# Training error: 0.204217854218
# Calculating best 10 features
# Training error: 0.204217854218
# Calculating best 9 features
# Training error: 0.204217854218
# Calculating best 8 features
# Training error: 0.204217854218
# Calculating best 7 features
# Training error: 0.204217854218
# Calculating best 6 features
# Training error: 0.204217854218
# Calculating best 5 features
# Training error: 0.204217854218
# Calculating best 4 features
# Training error: 0.204217854218
# Calculating best 3 features
# Training error: 0.204217854218
# Calculating best 2 features
# Training error: 0.207493857494
# Calculating best 1 features
# Training error: 0.220597870598
# Total time taken: 17.3236935139
#
# Best n: 11
# Calculating best 11 features
# Total time taken: 93.7287766933
# Lowest Test error: 0.16852966466
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16349342832575853}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14224296769438649}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.14801621422429678}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19002579535683572}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14899889448470705}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.1428571428571429}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16852966466036112}]
#
#
# L2 with c=2.9 and max_iter=50
#
# Calculating best 13 features
# Training error: 0.14696969697
# Calculating best 12 features
# Training error: 0.14656019656
# Calculating best 11 features
# Training error: 0.146355446355
# Calculating best 10 features
# Training error: 0.146396396396
# Calculating best 9 features
# Training error: 0.147092547093
# Calculating best 8 features
# Training error: 0.147256347256
# Calculating best 7 features
# Training error: 0.148771498771
# Calculating best 6 features
# Training error: 0.149918099918
# Calculating best 5 features
# Training error: 0.15171990172
# Calculating best 4 features
# Training error: 0.154791154791
# Calculating best 3 features
# Training error: 0.161752661753
# Calculating best 2 features
# Training error: 0.179402129402
# Calculating best 1 features
# Training error: 0.21895986896
# Total time taken: 46.6885421276
#
# Best n: 11
# Calculating best 11 features
# Total time taken: 176.101103067
# Lowest Test error: 0.152069770298
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16349342832575853}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14224296769438649}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.14801621422429678}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19002579535683572}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14899889448470705}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.1428571428571429}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16852966466036112}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.15206977029848912}]
#
#
# L2 with c=2.9 and max_iter=100
#
# Calculating best 13 features
# Training error: 0.149426699427
# Calculating best 12 features
# Training error: 0.148607698608
# Calculating best 11 features
# Training error: 0.148812448812
# Calculating best 10 features
# Training error: 0.148648648649
# Calculating best 9 features
# Training error: 0.149221949222
# Calculating best 8 features
# Training error: 0.149795249795
# Calculating best 7 features
# Training error: 0.150122850123
# Calculating best 6 features
# Training error: 0.152088452088
# Calculating best 5 features
# Training error: 0.154504504505
# Calculating best 4 features
# Training error: 0.156101556102
# Calculating best 3 features
# Training error: 0.162899262899
# Calculating best 2 features
# Training error: 0.181122031122
# Calculating best 1 features
# Training error: 0.219369369369
# Total time taken: 47.617803812
#
# Best n: 12
# Calculating best 12 features
# Total time taken: 82.2799119949
# Lowest Test error: 0.146173688736
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16349342832575853}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14224296769438649}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.14801621422429678}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19002579535683572}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14899889448470705}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.1428571428571429}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16852966466036112}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.15206977029848912}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 100, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14617368873602754}]
#
#
# L2 with c=3.0 and max_iter=10
#
# Calculating best 13 features
# Training error: 0.204832104832
# Calculating best 12 features
# Training error: 0.204832104832
# Calculating best 11 features
# Training error: 0.204832104832
# Calculating best 10 features
# Training error: 0.204873054873
# Calculating best 9 features
# Training error: 0.204873054873
# Calculating best 8 features
# Training error: 0.204873054873
# Calculating best 7 features
# Training error: 0.204873054873
# Calculating best 6 features
# Training error: 0.204873054873
# Calculating best 5 features
# Training error: 0.204914004914
# Calculating best 4 features
# Training error: 0.204995904996
# Calculating best 3 features
# Training error: 0.204791154791
# Calculating best 2 features
# Training error: 0.2085995086
# Calculating best 1 features
# Training error: 0.222072072072
# Total time taken: 17.7455716133
#
# Best n: 3
# Calculating best 3 features
# Total time taken: 46.9301195145
# Lowest Test error: 0.171109200344
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16349342832575853}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14224296769438649}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.14801621422429678}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19002579535683572}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14899889448470705}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.1428571428571429}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16852966466036112}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.15206977029848912}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 100, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14617368873602754}, {'classifier: ': 'Logistic L2', 'C': 3.0, 'max_iter': 10, 'features': ('education', 'marital-status', 'occupation'), 'error': 0.17110920034393806}]
#
#
# L2 with c=3.0 and max_iter=50
#
# Calculating best 13 features
# Training error: 0.148321048321
# Calculating best 12 features
# Training error: 0.147747747748
# Calculating best 11 features
# Training error: 0.148484848485
# Calculating best 10 features
# Training error: 0.148771498771
# Calculating best 9 features
# Training error: 0.149426699427
# Calculating best 8 features
# Training error: 0.149713349713
# Calculating best 7 features
# Training error: 0.15
# Calculating best 6 features
# Training error: 0.150900900901
# Calculating best 5 features
# Training error: 0.152334152334
# Calculating best 4 features
# Training error: 0.154954954955
# Calculating best 3 features
# Training error: 0.161670761671
# Calculating best 2 features
# Training error: 0.179770679771
# Calculating best 1 features
# Training error: 0.220352170352
# Total time taken: 47.9483103752
#
# Best n: 12
# Calculating best 12 features
# Total time taken: 82.3948209286
# Lowest Test error: 0.148139049257
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16349342832575853}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14224296769438649}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.14801621422429678}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19002579535683572}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14899889448470705}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.1428571428571429}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16852966466036112}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.15206977029848912}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 100, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14617368873602754}, {'classifier: ': 'Logistic L2', 'C': 3.0, 'max_iter': 10, 'features': ('education', 'marital-status', 'occupation'), 'error': 0.17110920034393806}, {'classifier: ': 'Logistic L2', 'C': 3.0, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14813904925684807}]
#
#
# L2 with c=3.0 and max_iter=100
#
# Calculating best 13 features
# Training error: 0.147870597871
# Calculating best 12 features
# Training error: 0.148361998362
# Calculating best 11 features
# Training error: 0.148525798526
# Calculating best 10 features
# Training error: 0.148648648649
# Calculating best 9 features
# Training error: 0.149426699427
# Calculating best 8 features
# Training error: 0.149262899263
# Calculating best 7 features
# Training error: 0.150368550369
# Calculating best 6 features
# Training error: 0.151638001638
# Calculating best 5 features
# Training error: 0.153685503686
# Calculating best 4 features
# Training error: 0.156715806716
# Calculating best 3 features
# Training error: 0.161916461916
# Calculating best 2 features
# Training error: 0.180139230139
# Calculating best 1 features
# Training error: 0.21981981982
# Total time taken: 47.8805012703
#
# Best n: 13
# Calculating best 13 features
# Total time taken: 53.49741292
# Lowest Test error: 0.149981574745
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16349342832575853}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14224296769438649}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.14801621422429678}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19002579535683572}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14899889448470705}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.1428571428571429}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16852966466036112}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.15206977029848912}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 100, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14617368873602754}, {'classifier: ': 'Logistic L2', 'C': 3.0, 'max_iter': 10, 'features': ('education', 'marital-status', 'occupation'), 'error': 0.17110920034393806}, {'classifier: ': 'Logistic L2', 'C': 3.0, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14813904925684807}, {'classifier: ': 'Logistic L2', 'C': 3.0, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.1499815747451173 ...
#
#
# L2 with c=3.1 and max_iter=10
#
# Calculating best 13 features
# Training error: 0.206511056511
# Calculating best 12 features
# Training error: 0.206511056511
# Calculating best 11 features
# Training error: 0.206511056511
# Calculating best 10 features
# Training error: 0.206552006552
# Calculating best 9 features
# Training error: 0.206552006552
# Calculating best 8 features
# Training error: 0.206552006552
# Calculating best 7 features
# Training error: 0.206552006552
# Calculating best 6 features
# Training error: 0.206552006552
# Calculating best 5 features
# Training error: 0.206552006552
# Calculating best 4 features
# Training error: 0.206552006552
# Calculating best 3 features
# Training error: 0.206961506962
# Calculating best 2 features
# Training error: 0.210196560197
# Calculating best 1 features
# Training error: 0.222727272727
# Total time taken: 17.4792740345
#
# Best n: 13
# Calculating best 13 features
# Total time taken: 21.1035432816
# Lowest Test error: 0.196658887115
# ...
#
#
# L2 with c=5.0 and max_iter=10
#
# Calculating best 13 features
# Training error: 0.202497952498
# Calculating best 12 features
# Training error: 0.202497952498
# Calculating best 11 features
# Training error: 0.202497952498
# Calculating best 10 features
# Training error: 0.202497952498
# Calculating best 9 features
# Training error: 0.202497952498
# Calculating best 8 features
# Training error: 0.202497952498
# Calculating best 7 features
# Training error: 0.202497952498
# Calculating best 6 features
# Training error: 0.202497952498
# Calculating best 5 features
# Training error: 0.202497952498
# Calculating best 4 features
# Training error: 0.20257985258
# Calculating best 3 features
# Training error: 0.202702702703
# Calculating best 2 features
# Training error: 0.206797706798
# Calculating best 1 features
# Training error: 0.220352170352
# Total time taken: 16.564265728
#
# Best n: 14
# Calculating best 14 features
# Total time taken: 16.8352108002
# Lowest Test error: 0.208082545142
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16349342832575853}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14224296769438649}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.14801621422429678}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19002579535683572}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14899889448470705}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.1428571428571429}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16852966466036112}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.15206977029848912}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 100, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14617368873602754}, {'classifier: ': 'Logistic L2', 'C': 3.0, 'max_iter': 10, 'features': ('education', 'marital-status', 'occupation'), 'error': 0.17110920034393806}, {'classifier: ': 'Logistic L2', 'C': 3.0, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14813904925684807}, {'classifier: ': 'Logistic L2', 'C': 3.0, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.1499815747451173 ...
#
#
# L2 with c=5.0 and max_iter=50
#
# Calculating best 13 features
# Training error: 0.14610974611
# Calculating best 12 features
# Training error: 0.145536445536
# Calculating best 11 features
# Training error: 0.14484029484
# Calculating best 10 features
# Training error: 0.1457002457
# Calculating best 9 features
# Training error: 0.145823095823
# Calculating best 8 features
# Training error: 0.146519246519
# Calculating best 7 features
# Training error: 0.147502047502
# Calculating best 6 features
# Training error: 0.150286650287
# Calculating best 5 features
# Training error: 0.15040950041
# Calculating best 4 features
# Training error: 0.155364455364
# Calculating best 3 features
# Training error: 0.159541359541
# Calculating best 2 features
# Training error: 0.179033579034
# Calculating best 1 features
# Training error: 0.218714168714
# Total time taken: 43.9516777992
#
# Best n: 11
# Calculating best 11 features
# Total time taken: 163.362910032
# Lowest Test error: 0.155386316177
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16349342832575853}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14224296769438649}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.14801621422429678}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19002579535683572}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14899889448470705}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.1428571428571429}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16852966466036112}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.15206977029848912}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 100, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14617368873602754}, {'classifier: ': 'Logistic L2', 'C': 3.0, 'max_iter': 10, 'features': ('education', 'marital-status', 'occupation'), 'error': 0.17110920034393806}, {'classifier: ': 'Logistic L2', 'C': 3.0, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14813904925684807}, {'classifier: ': 'Logistic L2', 'C': 3.0, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.1499815747451173 ...
#
#
# L2 with c=5.0 and max_iter=100
#
# Calculating best 13 features
# Training error: 0.147461097461
# Calculating best 12 features
# Training error: 0.147133497133
# Calculating best 11 features
# Training error: 0.147706797707
# Calculating best 10 features
# Training error: 0.147215397215
# Calculating best 9 features
# Training error: 0.148525798526
# Calculating best 8 features
# Training error: 0.148894348894
# Calculating best 7 features
# Training error: 0.150122850123
# Calculating best 6 features
# Training error: 0.150655200655
# Calculating best 5 features
# Training error: 0.151760851761
# Calculating best 4 features
# Training error: 0.153726453726
# Calculating best 3 features
# Training error: 0.160442260442
# Calculating best 2 features
# Training error: 0.177231777232
# Calculating best 1 features
# Training error: 0.219369369369
# Total time taken: 46.0584025383
#
# Best n: 12
# Calculating best 12 features
# Total time taken: 81.4476115704
# Lowest Test error: 0.148384719322
# [{'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss'), 'error': 0.16914383982311754}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14985873971256602}, {'classifier: ': 'Logistic L2', 'C': 2.6000000000000001, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.15010440977766859}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16349342832575853}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14224296769438649}, {'classifier: ': 'Logistic L2', 'C': 2.7000000000000002, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.14801621422429678}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 10, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.19002579535683572}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 50, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14899889448470705}, {'classifier: ': 'Logistic L2', 'C': 2.8000000000000003, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.1428571428571429}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 10, 'features': ('workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.16852966466036112}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week'), 'error': 0.15206977029848912}, {'classifier: ': 'Logistic L2', 'C': 2.8999999999999999, 'max_iter': 100, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14617368873602754}, {'classifier: ': 'Logistic L2', 'C': 3.0, 'max_iter': 10, 'features': ('education', 'marital-status', 'occupation'), 'error': 0.17110920034393806}, {'classifier: ': 'Logistic L2', 'C': 3.0, 'max_iter': 50, 'features': ('age', 'workclass', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.14813904925684807}, {'classifier: ': 'Logistic L2', 'C': 3.0, 'max_iter': 100, 'features': ('age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'), 'error': 0.1499815747451173 ...

# %%
with open('log_reg_l2_2.txt', 'w') as f:
    for it in grid_search:
        f.write('{}\n'.format(it))
