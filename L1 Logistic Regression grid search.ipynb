# %%
from time import time

import numpy as np

from sklearn.cross_validation import train_test_split
from sklearn.grid_search import ParameterGrid
from sklearn.feature_extraction import DictVectorizer as DV
from sklearn.linear_model import LogisticRegression

from get_data import data

# %%
df = data()

X = df[ [col for col in df if col not in ['class']]]
y = df['class'].values

# Binarize the categorical data using a DictVectorizer
# This requires the data be fed in the form of Python dicts
vectorizer = DV(sparse=False)
X_binarized = vectorizer.fit_transform( X.to_dict(orient='records') )


# Split into test and train sets
X_train, X_test, y_train, y_test = train_test_split(X_binarized, y, train_size=.8, random_state=42)

# %%
C = np.linspace(.1, 10, 100).tolist() + np.linspace(20,100, 5).tolist() + np.linspace(200, 1000, 9).tolist()

# %%
param_grid = list(ParameterGrid({'C': C, 'penalty': ['l1']}))

# %%
for params in param_grid:
    
    classifier = LogisticRegression(**params)

    # Fit the model to the training data
    t0 = time()
    classifier.fit(X_train, y_train)
    t1 = time()

    accuracy = classifier.score(X_test, y_test)
    error = (1 - accuracy)

    print '\nTest error: {} Time to train: {}'.format(error, (t1-t0))
    print 'Params: {}'.format(params)
# Out:
# Test error: 0.143559035775 Time to train: 0.336972951889
# Params: {'penalty': 'l1', 'C': 0.1}
#
# Test error: 0.142023645018 Time to train: 0.267817020416
# Params: {'penalty': 'l1', 'C': 0.2}
#
# Test error: 0.141409488715 Time to train: 0.168585062027
# Params: {'penalty': 'l1', 'C': 0.30000000000000004}
#
# Test error: 0.141102410563 Time to train: 0.754909038544
# Params: {'penalty': 'l1', 'C': 0.4}
#
# Test error: 0.141870105942 Time to train: 0.103921175003
# Params: {'penalty': 'l1', 'C': 0.5}
#
# Test error: 0.141563027791 Time to train: 0.513739109039
# Params: {'penalty': 'l1', 'C': 0.6}
#
# Test error: 0.141563027791 Time to train: 0.145889043808
# Params: {'penalty': 'l1', 'C': 0.7000000000000001}
#
# Test error: 0.140948871488 Time to train: 0.720541000366
# Params: {'penalty': 'l1', 'C': 0.8}
#
# Test error: 0.140795332412 Time to train: 0.602434158325
# Params: {'penalty': 'l1', 'C': 0.9}
#
# Test error: 0.140948871488 Time to train: 0.167183876038
# Params: {'penalty': 'l1', 'C': 1.0}
#
# Test error: 0.141255949639 Time to train: 0.474176883698
# Params: {'penalty': 'l1', 'C': 1.1}
#
# Test error: 0.141102410563 Time to train: 0.263606071472
# Params: {'penalty': 'l1', 'C': 1.2000000000000002}
#
# Test error: 0.141409488715 Time to train: 1.56702589989
# Params: {'penalty': 'l1', 'C': 1.3000000000000003}
#
# Test error: 0.140334715185 Time to train: 0.159078836441
# Params: {'penalty': 'l1', 'C': 1.4000000000000001}
#
# Test error: 0.140488254261 Time to train: 0.16077709198
# Params: {'penalty': 'l1', 'C': 1.5000000000000002}
#
# Test error: 0.140641793336 Time to train: 0.154812097549
# Params: {'penalty': 'l1', 'C': 1.6}
#
# Test error: 0.141255949639 Time to train: 0.351078033447
# Params: {'penalty': 'l1', 'C': 1.7000000000000002}
#
# Test error: 0.141409488715 Time to train: 0.141601800919
# Params: {'penalty': 'l1', 'C': 1.8000000000000003}
#
# Test error: 0.141409488715 Time to train: 0.253955125809
# Params: {'penalty': 'l1', 'C': 1.9000000000000001}
#
# Test error: 0.141409488715 Time to train: 0.274354934692
# Params: {'penalty': 'l1', 'C': 2.0}
#
# Test error: 0.140948871488 Time to train: 0.148192167282
# Params: {'penalty': 'l1', 'C': 2.1}
#
# Test error: 0.141716566866 Time to train: 0.265220165253
# Params: {'penalty': 'l1', 'C': 2.2}
#
# Test error: 0.141716566866 Time to train: 0.244070053101
# Params: {'penalty': 'l1', 'C': 2.3000000000000003}
#
# Test error: 0.141870105942 Time to train: 0.332659959793
# Params: {'penalty': 'l1', 'C': 2.4000000000000004}
#
# Test error: 0.142330723169 Time to train: 0.649150848389
# Params: {'penalty': 'l1', 'C': 2.5000000000000004}
#
# Test error: 0.141870105942 Time to train: 0.254868030548
# Params: {'penalty': 'l1', 'C': 2.6}
#
# Test error: 0.141409488715 Time to train: 0.208760976791
# Params: {'penalty': 'l1', 'C': 2.7}
#
# Test error: 0.142177184093 Time to train: 0.0658049583435
# Params: {'penalty': 'l1', 'C': 2.8000000000000003}
#
# Test error: 0.142023645018 Time to train: 0.317014932632
# Params: {'penalty': 'l1', 'C': 2.9000000000000004}
#
# Test error: 0.142177184093 Time to train: 0.340362071991
# Params: {'penalty': 'l1', 'C': 3.0000000000000004}
#
# Test error: 0.142484262245 Time to train: 0.111887931824
# Params: {'penalty': 'l1', 'C': 3.1}
#
# Test error: 0.141409488715 Time to train: 0.139248132706
# Params: {'penalty': 'l1', 'C': 3.2}
#
# Test error: 0.141716566866 Time to train: 0.16657781601
# Params: {'penalty': 'l1', 'C': 3.3000000000000003}
#
# Test error: 0.141563027791 Time to train: 0.14347910881
# Params: {'penalty': 'l1', 'C': 3.4000000000000004}
#
# Test error: 0.142177184093 Time to train: 0.256533145905
# Params: {'penalty': 'l1', 'C': 3.5000000000000004}
#
# Test error: 0.142023645018 Time to train: 0.18025803566
# Params: {'penalty': 'l1', 'C': 3.6}
#
# Test error: 0.142484262245 Time to train: 0.319401979446
# Params: {'penalty': 'l1', 'C': 3.7}
#
# Test error: 0.142023645018 Time to train: 0.207014083862
# Params: {'penalty': 'l1', 'C': 3.8000000000000003}
#
# Test error: 0.141409488715 Time to train: 0.146085977554
# Params: {'penalty': 'l1', 'C': 3.9000000000000004}
#
# Test error: 0.142330723169 Time to train: 0.345500946045
# Params: {'penalty': 'l1', 'C': 4.0}
#
# Test error: 0.142023645018 Time to train: 0.190966129303
# Params: {'penalty': 'l1', 'C': 4.1}
#
# Test error: 0.142023645018 Time to train: 0.183082818985
# Params: {'penalty': 'l1', 'C': 4.2}
#
# Test error: 0.142177184093 Time to train: 0.361742019653
# Params: {'penalty': 'l1', 'C': 4.3}
#
# Test error: 0.142023645018 Time to train: 0.190647125244
# Params: {'penalty': 'l1', 'C': 4.3999999999999995}
#
# Test error: 0.14263780132 Time to train: 0.227869033813
# Params: {'penalty': 'l1', 'C': 4.5}
#
# Test error: 0.142330723169 Time to train: 0.449125051498
# Params: {'penalty': 'l1', 'C': 4.6}
#
# Test error: 0.142177184093 Time to train: 0.21027302742
# Params: {'penalty': 'l1', 'C': 4.7}
#
# Test error: 0.141563027791 Time to train: 0.13961315155
# Params: {'penalty': 'l1', 'C': 4.8}
#
# Test error: 0.142023645018 Time to train: 0.171536207199
# Params: {'penalty': 'l1', 'C': 4.9}
#
# Test error: 0.142484262245 Time to train: 0.196238994598
# Params: {'penalty': 'l1', 'C': 5.0}
#
# Test error: 0.142177184093 Time to train: 0.200598955154
# Params: {'penalty': 'l1', 'C': 5.1}
#
# Test error: 0.142177184093 Time to train: 0.195228099823
# Params: {'penalty': 'l1', 'C': 5.2}
#
# Test error: 0.142330723169 Time to train: 0.208911180496
# Params: {'penalty': 'l1', 'C': 5.3}
#
# Test error: 0.142177184093 Time to train: 0.0836269855499
# Params: {'penalty': 'l1', 'C': 5.4}
#
# Test error: 0.142330723169 Time to train: 0.223401069641
# Params: {'penalty': 'l1', 'C': 5.5}
#
# Test error: 0.141870105942 Time to train: 0.186025857925
# Params: {'penalty': 'l1', 'C': 5.6}
#
# Test error: 0.142330723169 Time to train: 0.266275167465
# Params: {'penalty': 'l1', 'C': 5.7}
#
# Test error: 0.142330723169 Time to train: 0.175629854202
# Params: {'penalty': 'l1', 'C': 5.8}
#
# Test error: 0.142177184093 Time to train: 0.210388183594
# Params: {'penalty': 'l1', 'C': 5.9}
#
# Test error: 0.142023645018 Time to train: 0.194998025894
# Params: {'penalty': 'l1', 'C': 6.0}
#
# Test error: 0.142023645018 Time to train: 0.182942867279
# Params: {'penalty': 'l1', 'C': 6.1}
#
# Test error: 0.142330723169 Time to train: 0.27339220047
# Params: {'penalty': 'l1', 'C': 6.2}
#
# Test error: 0.142177184093 Time to train: 0.28569817543
# Params: {'penalty': 'l1', 'C': 6.3}
#
# Test error: 0.140948871488 Time to train: 0.123215913773
# Params: {'penalty': 'l1', 'C': 6.4}
#
# Test error: 0.141409488715 Time to train: 0.158339977264
# Params: {'penalty': 'l1', 'C': 6.5}
#
# Test error: 0.142484262245 Time to train: 0.18826007843
# Params: {'penalty': 'l1', 'C': 6.6}
#
# Test error: 0.141563027791 Time to train: 0.195559978485
# Params: {'penalty': 'l1', 'C': 6.7}
#
# Test error: 0.142177184093 Time to train: 0.228376150131
# Params: {'penalty': 'l1', 'C': 6.8}
#
# Test error: 0.142177184093 Time to train: 0.246984958649
# Params: {'penalty': 'l1', 'C': 6.9}
#
# Test error: 0.141870105942 Time to train: 0.0999889373779
# Params: {'penalty': 'l1', 'C': 7.0}
#
# Test error: 0.142023645018 Time to train: 0.255649089813
# Params: {'penalty': 'l1', 'C': 7.1}
#
# Test error: 0.141716566866 Time to train: 0.191696166992
# Params: {'penalty': 'l1', 'C': 7.2}
#
# Test error: 0.142791340396 Time to train: 0.060567855835
# Params: {'penalty': 'l1', 'C': 7.3}
#
# Test error: 0.142023645018 Time to train: 0.217685937881
# Params: {'penalty': 'l1', 'C': 7.4}
#
# Test error: 0.141563027791 Time to train: 0.171620845795
# Params: {'penalty': 'l1', 'C': 7.5}
#
# Test error: 0.141409488715 Time to train: 0.155084133148
# Params: {'penalty': 'l1', 'C': 7.6}
#
# Test error: 0.142177184093 Time to train: 0.296361923218
# Params: {'penalty': 'l1', 'C': 7.7}
#
# Test error: 0.142177184093 Time to train: 0.186683893204
# Params: {'penalty': 'l1', 'C': 7.8}
#
# Test error: 0.141563027791 Time to train: 0.268169879913
# Params: {'penalty': 'l1', 'C': 7.9}
#
# Test error: 0.142177184093 Time to train: 0.269772052765
# Params: {'penalty': 'l1', 'C': 8.0}
#
# Test error: 0.141102410563 Time to train: 0.150047063828
# Params: {'penalty': 'l1', 'C': 8.1}
#
# Test error: 0.142177184093 Time to train: 0.215528964996
# Params: {'penalty': 'l1', 'C': 8.2}
#
# Test error: 0.142023645018 Time to train: 0.220431804657
# Params: {'penalty': 'l1', 'C': 8.3}
#
# Test error: 0.142177184093 Time to train: 0.18630695343
# Params: {'penalty': 'l1', 'C': 8.4}
#
# Test error: 0.142177184093 Time to train: 0.200732946396
# Params: {'penalty': 'l1', 'C': 8.5}
#
# Test error: 0.142177184093 Time to train: 0.313506126404
# Params: {'penalty': 'l1', 'C': 8.6}
#
# Test error: 0.142023645018 Time to train: 0.191293001175
# Params: {'penalty': 'l1', 'C': 8.7}
#
# Test error: 0.142023645018 Time to train: 0.206250905991
# Params: {'penalty': 'l1', 'C': 8.8}
#
# Test error: 0.142177184093 Time to train: 0.209760904312
# Params: {'penalty': 'l1', 'C': 8.9}
#
# Test error: 0.142177184093 Time to train: 0.24239897728
# Params: {'penalty': 'l1', 'C': 9.0}
#
# Test error: 0.142177184093 Time to train: 0.219033002853
# Params: {'penalty': 'l1', 'C': 9.1}
#
# Test error: 0.142177184093 Time to train: 0.228958129883
# Params: {'penalty': 'l1', 'C': 9.2}
#
# Test error: 0.141563027791 Time to train: 0.148830890656
# Params: {'penalty': 'l1', 'C': 9.3}
#
# Test error: 0.141409488715 Time to train: 0.133017063141
# Params: {'penalty': 'l1', 'C': 9.4}
#
# Test error: 0.141102410563 Time to train: 0.117584943771
# Params: {'penalty': 'l1', 'C': 9.5}
#
# Test error: 0.142330723169 Time to train: 1.02953195572
# Params: {'penalty': 'l1', 'C': 9.6}
#
# Test error: 0.140948871488 Time to train: 0.104952096939
# Params: {'penalty': 'l1', 'C': 9.700000000000001}
#
# Test error: 0.142023645018 Time to train: 0.185263872147
# Params: {'penalty': 'l1', 'C': 9.8}
#
# Test error: 0.141716566866 Time to train: 0.166620016098
# Params: {'penalty': 'l1', 'C': 9.9}
#
# Test error: 0.141102410563 Time to train: 0.110710144043
# Params: {'penalty': 'l1', 'C': 10.0}
#
# Test error: 0.14263780132 Time to train: 0.232204914093
# Params: {'penalty': 'l1', 'C': 20.0}
#
# Test error: 0.141409488715 Time to train: 0.138370990753
# Params: {'penalty': 'l1', 'C': 40.0}
#
# Test error: 0.142330723169 Time to train: 0.168225049973
# Params: {'penalty': 'l1', 'C': 60.0}
#
# Test error: 0.141716566866 Time to train: 0.129207134247
# Params: {'penalty': 'l1', 'C': 80.0}
#
# Test error: 0.142330723169 Time to train: 0.170506000519
# Params: {'penalty': 'l1', 'C': 100.0}
#
# Test error: 0.141716566866 Time to train: 0.122450113297
# Params: {'penalty': 'l1', 'C': 200.0}
#
# Test error: 0.141870105942 Time to train: 0.151260852814
# Params: {'penalty': 'l1', 'C': 300.0}
#
# Test error: 0.142944879472 Time to train: 0.189764022827
# Params: {'penalty': 'l1', 'C': 400.0}
#
# Test error: 0.142330723169 Time to train: 0.15839099884
# Params: {'penalty': 'l1', 'C': 500.0}
#
# Test error: 0.142944879472 Time to train: 0.244996070862
# Params: {'penalty': 'l1', 'C': 600.0}
#
# Test error: 0.141716566866 Time to train: 0.132415056229
# Params: {'penalty': 'l1', 'C': 700.0}
#
# Test error: 0.142791340396 Time to train: 0.173042058945
# Params: {'penalty': 'l1', 'C': 800.0}
#
# Test error: 0.142023645018 Time to train: 0.150586128235
# Params: {'penalty': 'l1', 'C': 900.0}
#
# Test error: 0.14263780132 Time to train: 0.162935018539
# Params: {'penalty': 'l1', 'C': 1000.0}

# %%
results = []

for params in param_grid:
    
    classifier = LogisticRegression(**params)

    # Fit the model to the training data
    t0 = time()
    classifier.fit(X_train, y_train)
    t1 = time()

    accuracy = classifier.score(X_test, y_test)
    error = (1 - accuracy)
    
    results.append((params['C'], error))

# %%
min(results, key=lambda x: x[1])
# Out:
# (1.1, 0.14064179333640414)

# %%
for c,e in results:
    print('{},'.format(e)),
# Out:
# 0.14371257485, 0.142330723169, 0.141409488715, 0.141255949639, 0.142330723169, 0.141870105942, 0.141870105942, 0.141102410563, 0.140795332412, 0.141255949639, 0.140641793336, 0.141255949639, 0.141255949639, 0.141255949639, 0.141409488715, 0.140795332412, 0.141102410563, 0.141716566866, 0.141716566866, 0.141870105942, 0.140641793336, 0.140948871488, 0.142177184093, 0.141563027791, 0.142484262245, 0.141870105942, 0.141409488715, 0.141102410563, 0.142023645018, 0.141409488715, 0.141255949639, 0.143251957623, 0.141716566866, 0.142330723169, 0.142330723169, 0.141870105942, 0.142023645018, 0.142177184093, 0.142023645018, 0.142177184093, 0.142023645018, 0.141716566866, 0.142484262245, 0.142177184093, 0.141255949639, 0.142023645018, 0.142330723169, 0.141870105942, 0.142330723169, 0.14371257485, 0.141255949639, 0.142023645018, 0.142791340396, 0.141102410563, 0.141563027791, 0.142944879472, 0.142330723169, 0.141870105942, 0.142330723169, 0.142023645018, 0.142330723169, 0.141102410563, 0.141870105942, 0.141716566866, 0.142330723169, 0.141255949639, 0.142177184093, 0.141255949639, 0.142023645018, 0.141870105942, 0.141716566866, 0.141255949639, 0.141870105942, 0.142484262245, 0.142177184093, 0.141716566866, 0.141716566866, 0.141870105942, 0.142023645018, 0.141102410563, 0.142330723169, 0.142023645018, 0.141870105942, 0.141870105942, 0.142330723169, 0.142023645018, 0.141870105942, 0.142177184093, 0.142330723169, 0.142177184093, 0.141870105942, 0.141255949639, 0.141255949639, 0.141870105942, 0.141255949639, 0.141102410563, 0.141255949639, 0.142023645018, 0.142023645018, 0.142177184093, 0.142177184093, 0.141563027791, 0.142023645018, 0.141563027791, 0.14263780132, 0.141870105942, 0.142023645018, 0.141870105942, 0.142177184093, 0.141255949639, 0.141563027791, 0.141716566866, 0.142330723169, 0.142944879472,
